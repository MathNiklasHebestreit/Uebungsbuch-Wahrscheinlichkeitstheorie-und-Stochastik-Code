# %% [markdown]
# *This code is part of the book 'Übungs- und Lernbuch Wahrscheinlichkeitstheorie und Stochastik' by [Dr. Niklas Hebestreit-Düsing](https://dr-hebestreit.de/)*

# %% [markdown]
# **(Aufgabe 34, Konstruktion erzeugter $\sigma$-Algebren).** Es sei $X$ eine Menge, $n \in \N$ eine natürliche Zahl und $\mathfrak{E} := \{E_1 , \dotsc, E_n\}$ ein Mengensystem, das aus endlich vielen Teilmengen von $X$ besteht.
# Im Folgenden sollen Sie eine Konstruktionsmethode für die Berechnung der von $\mathfrak{E}$ erzeugten $\sigma$-Algebra auf $X$ nachvollziehen. Gehen Sie dazu wie folgt vor:

# %%
# Partition of the set X = {1,2,3,4}

P = [[1], [4], [2, 3]]  

"""
Generate the sigma algebra generated by the partition 'P'.
For each subset E in the powerset of 'P', compute the union of the subsets in E.
This gives all possible unions of the original partition elements.
"""
sigma_algebra = [list(set().union(*E)) for E in powerset(P)]

# Display the resulting sigma algebra
print(sigma_algebra)
# Out:
# [[], [1], [4], [1, 4], [2, 3], [1, 2, 3], [2, 3, 4], [1, 2, 3, 4]]

# %% [markdown]
# $\sum$

# %%
für $\alpha \in \{0,1\}^n$ gesetzt. Weisen Sie nach, dass das System
\begin{align*}
\mathfrak{P} := \big\{ E_\alpha \mid \alpha\in \{0,1\}^n \big\} \setminus \{\emptyset\}
\end{align*}
eine Partition von $X$ ist.
\item Es bezeichne $\mathfrak{A}$ das Mengensystem, das aus allen endlichen Vereinigungen von Mengen aus $\mathfrak{P}$ besteht, also
\begin{align*}
\mathfrak{A} := \left\{ \dbigcup_{E \, \in \, \mathfrak I} E \mid  \mathfrak I \subset \mathfrak{P} \right\}
\end{align*}
Beweisen Sie $\sigma(\mathfrak{E}) = \mathfrak{A}$, das heißt, die von $\mathfrak{E}$  erzeugte $\sigma$-Algebra stimmt mit $\mathfrak{A}$ überein. Bestätigen Sie Ihr Ergebnis mithilfe von \texttt{SageMath}.
\item Bestimmen Sie mithilfe der Konstruktionsmethode aus Teil (b) die vom System $\mathfrak{E} := \{ \{1\}, \{2,3\}\}$ erzeugte $\sigma$-Algebra auf $X := \{1,2,3,4\}$.
\item (Implementation des Konstruktionsverfahrens)\textbf{.} Implementieren Sie beispielsweise in \texttt{SageMath} die Funktion
\begin{align*}
\texttt{generate\_sigma\_algebras(k)}
\end{align*}
Diese berechnet für jede natürliche Zahl $k \in \N$ alle $\sigma$-Algebren über der Menge $\{1, \dotsc, k\}$. Bestimmen Sie anschließend alle $\sigma$-Algebren für $k \in \{1,2,3\}$. Entscheiden Sie weiter, ob das Mengensystem
\begin{align*}
\mathfrak{A} := \big\{ \emptyset, \{1\}, \{3\}, \{1,2\}, \{3,4\}, \{1,3,4\}, \{2,3,4\}, \{1,2,3,4\} \big\}
\end{align*}
eine $\sigma$-Algebra über der Menge $\{1,2,3,4\}$ definiert.
\end{enumerate}
\end{Aufgabe}
